# %%
# Out:
# 🎨 Genesis Research - Chart Organization Tool
#
# This script will help you organize your charts.
#
# Step 1: Creating category folders...
# ✅ Created folder: charts/Equities/
# ✅ Created folder: charts/Economics/
# ✅ Created folder: charts/Technical/
# ✅ Created folder: charts/Commodities/
# ✅ Created folder: charts/Fixed Income/
# ✅ Created folder: charts/Currencies/
# ✅ Created folder: charts/Cross Assets/
# ✅ Created folder: charts/Education/
#
# Step 2: Reversing insight IDs (newest = 1)...
# ✅ Reversed 29 insights (ID 1 is now newest)
#
# Step 3: Suggested file organization:
#
# 📋 Suggested chart organization:
#
# Category: Fixed Income
#   FROM: charts/Fixed Income/10‑Year Treasury vs DXY: Easing Path & the Insurance Cut_2025-10-09.svg
#   TO:   charts/Fixed Income/10‑Year Treasury vs DXY: Easing Path & the Insurance Cut_2025-10-09.svg
#
# Category: Commodities
#   FROM: charts/Commodities/Gold and Geopolitics: From Relief to Resilience_2025-10-11.svg
# ...
